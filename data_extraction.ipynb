# %%
# Import dependencies
import pandas as pd
from pathlib import Path
import numpy as np

# %%
#installed the necessary packages needed
#!pip install pandas
# Out:
# Requirement already satisfied: pandas in c:\users\user\.conda\envs\elvisenv\lib\site-packages (2.0.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\user\.conda\envs\elvisenv\lib\site-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\user\.conda\envs\elvisenv\lib\site-packages (from pandas) (2022.7)
# Requirement already satisfied: tzdata>=2022.1 in c:\users\user\.conda\envs\elvisenv\lib\site-packages (from pandas) (2023.3)
# Requirement already satisfied: numpy>=1.21.0 in c:\users\user\.conda\envs\elvisenv\lib\site-packages (from pandas) (1.23.5)
# Requirement already satisfied: six>=1.5 in c:\users\user\.conda\envs\elvisenv\lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)

# %%
# more libraries
import pandas as pd
from pathlib import Path
from zipfile import ZipFile
import urllib.request
import io
from io import BytesIO
import json
import requests
#from config import nrel_key

# %%
# Define URL of target table
url = "https://openapi.battmobiel.be/Vehicles/ActiveVehicles"

# %%
# Create Get request to retrieve JSON data from url
url_json = requests.get(url).json()
# Confirm link returned as value with "object" key from get request
#archive_link = url_json["object"]
#archive_link
url_json
# Out:
# [{'displayName': 'Ioniq 5, Casinoplein - besteld<br/><i>Casinoplein 26, 9000 Gent</i>',
#   'imageUrl': 'https://www.battmobility.com/Assets/Images/Vehicles/VehicleTypeID41.png',
#   'brandIcon': 'https://www.battmobility.com/Assets/Images/BrandIcons/Brandicon_Hyundai.jpg',
#   'availableInFormula': ['BattFun', 'BattFan', 'BattFanPlus'],
#   'availability': 'expected',
#   'baseAddress': 'Casinoplein 26, 9000 Gent',
#   'stationType': 'fixed',
#   'geoPosition': {'longitude': '3.7122036000', 'latitude': '51.0517505000'},
#   'vehicleInformation': {'brand': 'Hyundai',
#    'model': 'Ioniq 5',
#    'fuelType': 'electric',
#    'transmissionType': 'automatic'},
#   'isAlreadyInOption': False,
#   'expectedDeliveryDate': 'nvt',
#   'monthlyLeaseprice10KKmExVat': 'nvt',
#   'offerteurl': 'https://www.battmobility.be/offerte'},
#  {'displayName': 'Volvo C40 Muinkkaai<br/><i>Muinkkaai 34, 9000 Gent</i>',
#   'imageUrl': 'https://www.battmobility.com/Assets/Images/Vehicles/VehicleTypeID66.png',
#   'brandIcon': 'https://www.battmobility.com/Assets/Images/BrandIcons/Brandicon_Volvo.jpg',
#   'availableInFormula': ['BattFun', 'BattFan', 'BattFanPlus'],
#   'availability': 'active',
#   'baseAddress': 'Muinkkaai 34, 9000 Gent',
#   'stationType': 'fixed',
#   'geoPosition': {'longitude': '3.7287200000', 'latitude': '51.0449100000'},
#   'vehicleInformation': {'brand': 'Volvo',
#    'model': 'C40',
#    'fuelType': 'electric',
#    'transmissionType': 'automatic'},
#   'isAlreadyInOption': False,
#   'expectedDeliveryDate': 'nvt',
#   'monthlyLeaseprice10KKmExVat': 'nvt',
#   'offerteurl': 'https://www.battmobility.be/offerte'},
#  {'displayName': 'Ioniq 5 Vaderlandstraat (Stationsbuurt Zuid) - besteld<br/><i>Vaderlandstraat 3, 9000 Gent</i>',
#   'imageUrl': 'https://www.battmobility.com/Assets/Images/Vehicles/VehicleTypeID41.png',
#   'brandIcon': 'https://www.battmobility.com/Assets/Images/BrandIcons/Brandicon_Hyundai.jpg',
#   'availableInFormula': ['BattFun', 'BattFan', 'BattFanPlus'],
#   'availability': 'expected',
#   'baseAddress': 'Vaderlandstraat 3, 9000 Gent',
#   'stationType': 'fixed',
#   'geoPosition': {'longitude': '3.7151033000', 'latitude': '51.0314963000'},
#   'vehicleInformation': {'brand': 'Hyundai',
#    'model': 'Ioniq 5',
#    'fuelType': 'electric',
#    'transmissionType': 'automatic'},
#   'isAlreadyInOption': False,
#   'expectedDeliveryDate': 'nvt',
#   'monthlyLeaseprice10KKmExVat': 'nvt',
#   'offerteurl': 'https://www.battmobility.be/offerte'},
#  {'displayName': 'Volkswagen ID.3 Zwijnaardsesteenweg (Stationsbuurt Zuid) - besteld<br/><i>Zwijnaardsesteenweg 221, 9000 Gent</i>',
#   'imageUrl': 'https://www.battmobility.com/Assets/Images/Vehicles/VehicleTypeID33.png',
#   'brandIcon': 'https://www.battmobility.com/Assets/Images/BrandIcons/Brandicon_Volkswagen.jpg',
#   'availableInFormula': ['BattFun', 'BattFan', 'BattFanPlus'],
#   'availability': 'expected',
#   'baseAddress': 'Zwijnaardsesteenweg 221, 9000 Gent',
#   'stationType': 'fixed',
#   'geoPosition': {'longitude': '3.7231258000', 'latitude': '51.0314269000'},
#   'vehicleInformation': {'brand': 'Volkswagen',
#    'model': 'ID.3 Pro',
#    'fuelType': 'electric',
#    'transmissionType': 'automatic'},
#   'isAlreadyInOption': False,
#   'expectedDeliveryDate': 'nvt',
#   'monthlyLeaseprice10KKmExVat': 'nvt',
#   'offerteurl': 'https://www.battmobility.be/offerte'},
#  {'displayName': 'EV6 Merelbeke<br/><i>Mellestraat 3 , 9000 Gent</i>',
#   'imageUrl': 'https://www.battmobility.com/Assets/Images/Vehicles/VehicleTypeID53.png',
#   'brandIcon': 'https://www.battmobility.com/Assets/Images/BrandIcons/Brandicon_Kia.jpg',
#   'availableInFormula': ['BattFun', 'BattFan', 'BattFanPlus'],
#   'availability': 'active',
#   'baseAddress': 'Mellestraat 3 , 9000 Gent',
#   'stationType': 'fixed',
#   'geoPosition': {'longitude': '3.7330800000', 'latitude': '51.0390500000'},
#   'vehicleInformation': {'brand': 'Kia',
#    'model': 'EV6',
#    'fuelType': 'electric',
#    'transmissionType': 'automatic'},
#   'isAlreadyInOption': False,
#   'expectedDeliveryDate': 'nvt',
#   'monthlyLeaseprice10KKmExVat': 'nvt',
#   'offerteurl': 'https://www.battmobility.be/offerte'},
#  {'displayName': 'Volkswagen ID.3 Plateaustraat (Binnenstad) - besteld<br/><i>Jozef Plateaustraat 20, 9000 Gent</i>',
#   'imageUrl': 'https://www.battmobility.com/Assets/Images/Vehicles/VehicleTypeID33.png',
#   'brandIcon': 'https://www.battmobility.com/Assets/Images/BrandIcons/Brandicon_Volkswagen.jpg',
#   'availableInFormula': ['BattFun', 'BattFan', 'BattFanPlus'],
#   'availability': 'expected',
#   'baseAddress': 'Jozef Plateaustraat 20, 9000 Gent',
#   'stationType': 'fixed',
#   'geoPosition': {'longitude': '3.7236052000', 'latitude': '51.0461445000'},
#   'vehicleInformation': {'brand': 'Volkswagen',
#    'model': 'ID.3 Pro',
#    'fuelType': 'electric',
#    'transmissionType': 'automatic'},
#   'isAlreadyInOption': False,
#   'expectedDeliveryDate': 'nvt',
#   'monthlyLeaseprice10KKmExVat': 'nvt',
#   'offerteurl': 'https://www.battmobility.be/offerte'},
#  {'displayName': 'Kona Hoogstraat<br/><i>Hoogstraat 19, 9000 Gent</i>',
#   'imageUrl': 'https://www.battmobility.com/Assets/Images/Vehicles/VehicleTypeID5.png',
#   'brandIcon': 'https://www.battmobility.com/Assets/Images/BrandIcons/Brandicon_Hyundai.jpg',
#   'availableInFormula': ['BattFun', 'BattFan', 'BattFanPlus'],
#   'availability': 'active',
#   'baseAddress': 'Hoogstraat 19, 9000 Gent',
#   'stationType': 'fixed',
#   'geoPosition': {'longitude': '3.7153000000', 'latitude': '51.0545400000'},
#   'vehicleInformation': {'brand': 'Hyundai',
#    'model': 'Kona',
#    'fuelType': 'electric',
#    'transmissionType': 'automatic'},
#   'isAlreadyInOption': False,
#   'expectedDeliveryDate': 'nvt',
#   'monthlyLeaseprice10KKmExVat': 'nvt',
#   'offerteurl': 'https://www.battmobility.be/offerte'},
#  {'displayName': 'Peugeot e-208 Constant Permekelaan - besteld<br/><i>Constant Permekelaan 54, 9830 Sint-Martens-Latem</i>',
#   'imageUrl': 'https://www.battmobility.com/Assets/Images/Vehicles/VehicleTypeID45.png',
#   'brandIcon': 'https://www.battmobility.com/Assets/Images/BrandIcons/Brandicon_Peugeot.jpg',
#   'availableInFormula': ['BattFun', 'BattFan', 'BattFanPlus'],
#   'availability': 'expected',
#   'baseAddress': 'Constant Permekelaan 54, 9830 Sint-Martens-Latem',
#   'stationType': 'fixed',
#   'geoPosition': {'longitude': '3.6280300000', 'latitude': '51.0012870000'},
#   'vehicleInformation': {'brand': 'Peugeot',
#    'model': 'e-208',
#    'fuelType': 'electric',
#    'transmissionType': 'automatic'},
#   'isAlreadyInOption': False,
#   'expectedDeliveryDate': 'nvt',
#   'monthlyLeaseprice10KKmExVat': 'nvt',
#   'offerteurl': 'https://www.battmobility.be/offerte'},
#  {'displayName': 'Polestar 2 Groene Vallei (Brugse Poort - Rooigem)<br/><i>Johannes Schrantstraat 1, 9000 Gent</i>',
#   'imageUrl': 'https://www.battmobility.com/Assets/Images/Vehicles/VehicleTypeID26.png',
#   'brandIcon': 'https://www.battmobility.com/Assets/Images/BrandIcons/Brandicon_Polestar.jpg',
#   'availableInFormula': ['BattFanPlus'],
#   'availability': 'active',
#   'baseAddress': 'Johannes Schrantstraat 1, 9000 Gent',
#   'stationType': 'fixed',
#   'geoPosition': {'longitude': '3.7016800000', 'latitude': '51.0538500000'},
#   'vehicleInformation': {'brand': 'Polestar',
#    'model': '2',
#    'fuelType': 'electric',
#    'transmissionType': 'automatic'},
#   'isAlreadyInOption': False,
#   'expectedDeliveryDate': 'nvt',
#   'monthlyLeaseprice10KKmExVat': 'nvt',
#   'offerteurl': 'https://www.battmobility.be/offerte'},
#  {'displayName': 'Peugeot e-Rifter - besteld',
#   'imageUrl': 'https://www.battmobility.com/Assets/Images/Vehicles/VehicleTypeID51.png',
#   'brandIcon': 'https://www.battmobility.com/Assets/Images/BrandIcons/Brandicon_Peugeot.jpg',
#   'availableInFormula': ['BattFun', 'BattFan', 'BattFanPlus'],
#   'availability': 'expected',
#   'baseAddress': '',
#   'stationType': 'fixed',
#   'geoPosition': {'longitude': '3.7298', 'latitude': '51.04333'},
#   'vehicleInformation': {'brand': 'Peugeot',
#    'model': 'e-Rifter',
#    'fuelType': 'electric',
#    'transmissionType': 'automatic'},
#   'isAlreadyInOption': False,
#   'expectedDeliveryDate': 'nvt',
#   'monthlyLeaseprice10KKmExVat': 'nvt',
#   'offerteurl': 'https://www.battmobility.be/offerte'},
#  {'displayName': 'Peugeot e-208GT (preorder leveringsdatum 5 May 2023)',
#   'imageUrl': 'https://www.battmobility.com/Assets/Images/Vehicles/VehicleTypeID45.png',
#   'brandIcon': 'https://www.battmobility.com/Assets/Images/BrandIcons/Brandicon_Peugeot.jpg',
#   'availableInFormula': ['BattFun', 'BattFan', 'BattFanPlus'],
#   'availability': 'preordered',
#   'baseAddress': '',
#   'stationType': 'fixed',
#   'geoPosition': {'longitude': '3.7298', 'latitude': '51.04333'},
#   'vehicleInformation': {'brand': 'Peugeot',
#    'model': 'e-208',
#    'fuelType': 'electric',
#    'transmissionType': 'automatic'},
#   'isAlreadyInOption': False,
#   'expectedDeliveryDate': '5 May 2023',
#   'monthlyLeaseprice10KKmExVat': 'nvt',
#   'offerteurl': 'https://www.battmobility.be/offerte'},
#  {'displayName': 'Kona Tortelduifstraat - besteld<br/><i>Tortelduifstraat 77, 9000 Gent</i>',
#   'imageUrl': 'https://www.battmobility.com/Assets/Images/Vehicles/VehicleTypeID5.png',
#   'brandIcon': 'https://www.battmobility.com/Assets/Images/BrandIcons/Brandicon_Hyundai.jpg',
#   'availableInFormula': ['BattFun', 'BattFan', 'BattFanPlus'],
#   'availability': 'expected',
#   'baseAddress': 'Tortelduifstraat 77, 9000 Gent',
#   'stationType': 'fixed',
#   'geoPosition': {'longitude': '3.7298', 'latitude': '51.04333'},
#   'vehicleInformation': {'brand': 'Hyundai',
#    'model': 'Kona 64kWh',
#    'fuelType': 'electric',
#    'transmissionType': 'automatic'},
#   'isAlreadyInOption': False,
#   'expectedDeliveryDate': 'nvt',
#   'monthlyLeaseprice10KKmExVat': 'nvt',
#   'offerteurl': 'https://www.battmobility.be/offerte'},
#  {'displayName': 'Peugeot e-208 Lovendegem<br/><i>Tennisstraat 20, 9920 Lievegem</i>',
#   'imageUrl': 'https://www.battmobility.com/Assets/Images/Vehicles/VehicleTypeID45.png',
#   'brandIcon': 'https://www.battmobility.com/Assets/Images/BrandIcons/Brandicon_Peugeot.jpg',
#   'availableInFormula': ['BattFun', 'BattFan', 'BattFanPlus'],
#   'availability': 'active',
#   'baseAddress': 'Tennisstraat 20, 9920 Lievegem',
#   'stationType': 'fixed',
#   'geoPosition': {'longitude': '3.6081232000', 'latitude': '51.0988884000'},
#   'vehicleInformation': {'brand': 'Peugeot',
#    'model': 'e-208',
#    'fuelType': 'electric',
#    'transmissionType': 'automatic'},
#   'isAlreadyInOption': False,
#   'expectedDeliveryDate': 'nvt',
#   'monthlyLeaseprice10KKmExVat': 'nvt',
#   'offerteurl': 'https://www.battmobility.be/offerte'},
#  {'displayName': 'Peugeot e-208 Laarne<br/><i>Haeghensgoed 9, 9270 Laarne</i>',
#   'imageUrl': 'https://www.battmobility.com/Assets/Images/Vehicles/VehicleTypeID45.png',
#   'brandIcon': 'https://www.battmobility.com/Assets/Images/BrandIcons/Brandicon_Peugeot.jpg',
#   'availableInFormula': ['BattFun', 'BattFan', 'BattFanPlus'],
#   'availability': 'active',
#   'baseAddress': 'Haeghensgoed 9, 9270 Laarne',
#   'stationType': 'fixed',
#   'geoPosition': {'longitude': '3.8620403000', 'latitude': '51.0284655000'},
#   'vehicleInformation': {'brand': 'Peugeot',
#    'model': 'e-208',
#    'fuelType': 'electric',
#    'transmissionType': 'automatic'},
#   'isAlreadyInOption': False,
#   'expectedDeliveryDate': 'nvt',
#   'monthlyLeaseprice10KKmExVat': 'nvt',
#   'offerteurl': 'https://www.battmobility.be/offerte'},
#  {'displayName': 'Zoe Meulestee<br/><i>Meulesteedsesteenweg 438, 9000 Gent</i>',
#   'imageUrl': 'https://www.battmobility.com/Assets/Images/Vehicles/VehicleTypeID20.png',
#   'brandIcon': 'https://www.battmobility.com/Assets/Images/BrandIcons/Brandicon_Renault.jpg',
#   'availableInFormula': ['BattFun', 'BattFan', 'BattFanPlus'],
#   'availability': 'active',
#   'baseAddress': '

#    'fuelType': 'electric',
#    'transmissionType': 'automatic'},
#   'isAlreadyInOption': False,
#   'expectedDeliveryDate': 'nvt',
#   'monthlyLeaseprice10KKmExVat': 'nvt',
#   'offerteurl': 'https://www.battmobility.be/offerte'},
#  {'displayName': 'Kia e-Niro K Waeriplein (Brugse Poort - Rooigem)<br/><i>Karel Waeriplein 109, 9000 Gent</i>',
#   'imageUrl': 'https://www.battmobility.com/Assets/Images/Vehicles/VehicleTypeID4.png',
#   'brandIcon': 'https://www.battmobility.com/Assets/Images/BrandIcons/Brandicon_Kia.jpg',
#   'availableInFormula': ['BattFun', 'BattFan', 'BattFanPlus'],
#   'availability': 'active',
#   'baseAddress': 'Karel Waeriplein 109, 9000 Gent',
#   'stationType': 'fixed',
#   'geoPosition': {'longitude': '3.7042400000', 'latitude': '51.0585300000'},
#   'vehicleInformation': {'brand': 'Kia',
#    'model': 'e-Niro',
#    'fuelType': 'electric',
#    'transmissionType': 'automatic'},
#   'isAlreadyInOption': False,
#   'expectedDeliveryDate': 'nvt',
#   'monthlyLeaseprice10KKmExVat': 'nvt',
#   'offerteurl': 'https://www.battmobility.be/offerte'},
#  {'displayName': 'Kona F. Ferrerlaan (Bloemekenswijk)<br/><i>Francisco Ferrerlaan 88a, 9000 Gent</i>',
#   'imageUrl': 'https://www.battmobility.com/Assets/Images/Vehicles/VehicleTypeID5.png',
#   'brandIcon': 'https://www.battmobility.com/Assets/Images/BrandIcons/Brandicon_Hyundai.jpg',
#   'availableInFormula': ['BattFun', 'BattFan', 'BattFanPlus'],
#   'availability': 'active',
#   'baseAddress': 'Francisco Ferrerlaan 88a, 9000 Gent',
#   'stationType': 'fixed',
#   'geoPosition': {'longitude': '3.7023440000', 'latitude': '51.0693100000'},
#   'vehicleInformation': {'brand': 'Hyundai',
#    'model': 'Kona',
#    'fuelType': 'electric',
#    'transmissionType': 'automatic'},
#   'isAlreadyInOption': False,
#   'expectedDeliveryDate': 'nvt',
#   'monthlyLeaseprice10KKmExVat': 'nvt',
#   'offerteurl': 'https://www.battmobility.be/offerte'},
#  {'displayName': 'Kia e-Niro Groenebriel<br/><i>Groenebriel 1, 9000 Gent</i>',
#   'imageUrl': 'https://www.battmobility.com/Assets/Images/Vehicles/VehicleTypeID4.png',
#   'brandIcon': 'https://www.battmobility.com/Assets/Images/BrandIcons/Brandicon_Kia.jpg',
#   'availableInFormula': ['BattFun', 'BattFan', 'BattFanPlus'],
#   'availability': 'active',
#   'baseAddress': 'Groenebriel 1, 9000 Gent',
#   'stationType': 'fixed',
#   'geoPosition': {'longitude': '3.7215097000', 'latitude': '51.0618537000'},
#   'vehicleInformation': {'brand': 'Kia',
#    'model': 'e-Niro',
#    'fuelType': 'electric',
#    'transmissionType': 'automatic'},
#   'isAlreadyInOption': False,
#   'expectedDeliveryDate': 'nvt',
#   'monthlyLeaseprice10KKmExVat': 'nvt',
#   'offerteurl': 'https://www.battmobility.be/offerte'},
#  {'displayName': 'Audi Q4 e-Tron Nieuwe Dokken (Muide - Meulestede - Afrikalaan)<br/><i>Kompasplein 20, 9000 Gent</i>',
#   'imageUrl': 'https://www.battmobility.com/Assets/Images/Vehicles/VehicleTypeID50.png',
#   'brandIcon': 'https://www.battmobility.com/Assets/Images/BrandIcons/Brandicon_Audi.jpg',
#   'availableInFormula': ['BattFun', 'BattFan', 'BattFanPlus'],
#   'availability': 'active',
#   'baseAddress': 'Kompasplein 20, 9000 Gent',
#   'stationType': 'fixed',
#   'geoPosition': {'longitude': '3.7373799000', 'latitude': '51.0647036000'},
#   'vehicleInformation': {'brand': 'Audi',
#    'model': 'Q4 e-tron',
#    'fuelType': 'electric',
#    'transmissionType': 'automatic'},
#   'isAlreadyInOption': False,
#   'expectedDeliveryDate': 'nvt',
#   'monthlyLeaseprice10KKmExVat': 'nvt',
#   'offerteurl': 'https://www.battmobility.be/offerte'},
#  {'displayName': 'New Zoe Burggravenlaan (Stationsbuurt Noord)<br/><i>Burggravenlaan 30, 9000 Gent</i>',
#   'imageUrl': 'https://www.battmobility.com/Assets/Images/Vehicles/VehicleTypeID2.png',
#   'brandIcon': 'https://www.battmobility.com/Assets/Images/BrandIcons/Brandicon_Renault.jpg',
#   'availableInFormula': ['BattFun', 'BattFan', 'BattFanPlus'],
#   'availability': 'active',
#   'baseAddress': 'Burggravenlaan 30, 9000 Gent',
#   'stationType': 'fixed',
#   'geoPosition': {'longitude': '3.6886100000', 'latitude': '51.0661500000'},
#   'vehicleInformation': {'brand': 'Renault',
#    'model': 'New Zoe',
#    'fuelType': 'electric',
#    'transmissionType': 'automatic'},
#   'isAlreadyInOption': False,
#   'expectedDeliveryDate': 'nvt',
#   'monthlyLeaseprice10KKmExVat': 'nvt',
#   'offerteurl': 'https://www.battmobility.be/offerte'},
#  {'displayName': 'New Zoe Bomastraat<br/><i>Bomastraat 16 , 9000 Gent</i>',
#   'imageUrl': 'https://www.battmobility.com/Assets/Images/Vehicles/VehicleTypeID2.png',
#   'brandIcon': 'https://www.battmobility.com/Assets/Images/BrandIcons/Brandicon_Renault.jpg',
#   'availableInFormula': ['BattFun', 'BattFan', 'BattFanPlus'],
#   'availability': 'active',
#   'baseAddress': 'Bomastraat 16 , 9000 Gent',
#   'stationType': 'fixed',
#   'geoPosition': {'longitude': '3.7320756000', 'latitude': '51.0617730000'},
#   'vehicleInformation': {'brand': 'Renault',
#    'model': 'New Zoe',
#    'fuelType': 'electric',
#    'transmissionType': 'automatic'},
#   'isAlreadyInOption': False,
#   'expectedDeliveryDate': 'nvt',
#   'monthlyLeaseprice10KKmExVat': 'nvt',
#   'offerteurl': 'https://www.battmobility.be/offerte'},
#  {'displayName': 'New Zoe Wolterslaan<br/><i>Wolterslaan 103, 9040 Gent</i>',
#   'imageUrl': 'https://www.battmobility.com/Assets/Images/Vehicles/VehicleTypeID2.png',
#   'brandIcon': 'https://www.battmobility.com/Assets/Images/BrandIcons/Brandicon_Renault.jpg',
#   'availableInFormula': ['BattFun', 'BattFan', 'BattFanPlus'],
#   'availability': 'active',
#   'baseAddress': 'Wolterslaan 103, 9040 Gent',
#   'stationType': 'fixed',
#   'geoPosition': {'longitude': '3.7494491000', 'latitude': '51.0486612000'},
# ...
#   'imageUrl': 'https://www.battmobility.com/Assets/Images/Vehicles/VehicleTypeID60.png',
#   'brandIcon': 'https://www.battmobility.com/Assets/Images/BrandIcons/Brandicon_Tesla.jpg',
#   'availableInFormula': ['BattFun', 'BattFan', 'BattFanPlus'],
#   'availability': 'preordered',
#   'baseAddress': 'Muinklaan 16, 9000 Gent',
#   'stationType': 'fixed',
#   'geoPosition': {'longitude': '3.7317043000', 'latitude': '51.0431454000'},
#   'vehicleInformation': {'brand': 'Tesla',
#    'model': 'Model X',
#    'fuelType': 'electric',
#    'transmissionType': 'automatic'},
#   'isAlreadyInOption': False,
#   'expectedDeliveryDate': 'ongekend',
#   'monthlyLeaseprice10KKmExVat': 'nvt',
#   'offerteurl': 'https://www.battmobility.be/offerte'},
#  {'displayName': 'Polestar 2 François Laurentplein<br/><i>François Laurentplein 1 (2e paal), 9000 Gent</i>',
#   'imageUrl': 'https://www.battmobility.com/Assets/Images/Vehicles/VehicleTypeID26.png',
#   'brandIcon': 'https://www.battmobility.com/Assets/Images/BrandIcons/Brandicon_Polestar.jpg',
#   'availableInFormula': ['BattFanPlus'],
#   'availability': 'active',
#   'baseAddress': 'François Laurentplein 1 (2e paal), 9000 Gent',
#   'stationType': 'fixed',
#   'geoPosition': {'longitude': '3.7281400000', 'latitude': '51.0513800000'},
#   'vehicleInformation': {'brand': 'Polestar',
#    'model': '2',
#    'fuelType': 'electric',
#    'transmissionType': 'automatic'},
#   'isAlreadyInOption': False,
#   'expectedDeliveryDate': 'nvt',
#   'monthlyLeaseprice10KKmExVat': 'nvt',
#   'offerteurl': 'https://www.battmobility.be/offerte'},
#  {'displayName': 'Ioniq 5, Gentbrugge - besteld<br/><i>Ooievaarsnest 23, 9050 Gentbrugge</i>',
#   'imageUrl': 'https://www.battmobility.com/Assets/Images/Vehicles/VehicleTypeID41.png',
#   'brandIcon': 'https://www.battmobility.com/Assets/Images/BrandIcons/Brandicon_Hyundai.jpg',
#   'availableInFormula': ['BattFun', 'BattFan', 'BattFanPlus'],
#   'availability': 'expected',
#   'baseAddress': 'Ooievaarsnest 23, 9050 Gentbrugge',
#   'stationType': 'fixed',
#   'geoPosition': {'longitude': '3.7716599000', 'latitude': '51.0352509000'},
#   'vehicleInformation': {'brand': 'Hyundai',
#    'model': 'Ioniq 5',
#    'fuelType': 'electric',
#    'transmissionType': 'automatic'},
#   'isAlreadyInOption': False,
#   'expectedDeliveryDate': 'nvt',
#   'monthlyLeaseprice10KKmExVat': 'nvt',
#   'offerteurl': 'https://www.battmobility.be/offerte'},
#  {'displayName': 'Volvo XC40 Burggravenlaan - besteld<br/><i>Burggravenlaan 264, 9000 Gent</i>',
#   'imageUrl': 'https://www.battmobility.com/Assets/Images/Vehicles/VehicleTypeID43.png',
#   'brandIcon': 'https://www.battmobility.com/Assets/Images/BrandIcons/Brandicon_Volvo.jpg',
#   'availableInFormula': ['BattFun', 'BattFan', 'BattFanPlus'],
#   'availability': 'expected',
#   'baseAddress': 'Burggravenlaan 264, 9000 Gent',
#   'stationType': 'fixed',
#   'geoPosition': {'longitude': '3.7276200000', 'latitude': '51.0320838000'},
#   'vehicleInformation': {'brand': 'Volvo',
#    'model': 'XC40',
#    'fuelType': 'electric',
#    'transmissionType': 'automatic'},
#   'isAlreadyInOption': False,
#   'expectedDeliveryDate': 'nvt',
#   'monthlyLeaseprice10KKmExVat': 'nvt',
#   'offerteurl': 'https://www.battmobility.be/offerte'},
#  {'displayName': 'Peugeot e-208GT (preorder leveringsdatum 5 May 2023)',
#   'imageUrl': 'https://www.battmobility.com/Assets/Images/Vehicles/VehicleTypeID45.png',
#   'brandIcon': 'https://www.battmobility.com/Assets/Images/BrandIcons/Brandicon_Peugeot.jpg',
#   'availableInFormula': ['BattFun', 'BattFan', 'BattFanPlus'],
#   'availability': 'preordered',
#   'baseAddress': '',
#   'stationType': 'fixed',
#   'geoPosition': {'longitude': '3.7298', 'latitude': '51.04333'},
#   'vehicleInformation': {'brand': 'Peugeot',
#    'model': 'e-208',
#    'fuelType': 'electric',
#    'transmissionType': 'automatic'},
#   'isAlreadyInOption': False,
#   'expectedDeliveryDate': '5 May 2023',
#   'monthlyLeaseprice10KKmExVat': 'nvt',
#   'offerteurl': 'https://www.battmobility.be/offerte'},
#  {'displayName': 'Hyundai Ioniq 5Long Range (preorder leveringsdatum 12 Jan 2023)',
#   'imageUrl': 'https://www.battmobility.com/Assets/Images/Vehicles/VehicleTypeID41.png',
#   'brandIcon': 'https://www.battmobility.com/Assets/Images/BrandIcons/Brandicon_Hyundai.jpg',
#   'availableInFormula': ['BattFun', 'BattFan', 'BattFanPlus'],
#   'availability': 'preordered',
#   'baseAddress': '',
#   'stationType': 'fixed',
#   'geoPosition': {'longitude': '3.7298', 'latitude': '51.04333'},
#   'vehicleInformation': {'brand': 'Hyundai',
#    'model': 'Ioniq 5',
#    'fuelType': 'electric',
#    'transmissionType': 'automatic'},
#   'isAlreadyInOption': False,
#   'expectedDeliveryDate': '12 Jan 2023',
#   'monthlyLeaseprice10KKmExVat': 'nvt',
#   'offerteurl': 'https://www.battmobility.be/offerte'},
#  {'displayName': 'Peugeot e-Expert Wondelgem (Wondelgem) - besteld<br/><i>Botestraat 131, 9032 Wondelgem</i>',
#   'imageUrl': 'https://www.battmobility.com/Assets/Images/Vehicles/VehicleTypeID72.png',
#   'brandIcon': 'https://www.battmobility.com/Assets/Images/BrandIcons/Brandicon_Peugeot.jpg',
#   'availableInFormula': ['BattFun', 'BattFan', 'BattFanPlus'],
#   'availability': 'expected',
#   'baseAddress': 'Botestraat 131, 9032 Wondelgem',
#   'stationType': 'fixed',
#   'geoPosition': {'longitude': '3.6954030000', 'latitude': '51.0823167000'},
#   'vehicleInformation': {'brand': 'Peugeot',
#    'model': 'e-Expert',
#    'fuelType': 'electric',
#    'transmissionType': 'automatic'},
#   'isAlreadyInOption': False,
#   'expectedDeliveryDate': 'nvt',
#   'monthlyLeaseprice10KKmExVat': 'nvt',
#   'offerteurl': 'https://www.battmobility.be/offerte'},
#  {'displayName': 'Tesla Model 3 Tuinwijklaan<br/><i>Tuinwijklaan 20, 9000 Gent</i>',
#   'imageUrl': 'https://www.battmobility.com/Assets/Images/Vehicles/VehicleTypeID37.png',
#   'brandIcon': 'https://www.battmobility.com/Assets/Images/BrandIcons/Brandicon_Tesla.jpg',
#   'availableInFormula': ['BattFanPlus'],
#   'availability': 'active',
#   'baseAddress': 'Tuinwijklaan 20, 9000 Gent',
#   'stationType': 'fixed',
#   'geoPosition': {'longitude': '3.7115548000', 'latitude': '51.0321677000'},
#   'vehicleInformation': {'brand': 'Tesla',
#    'model': 'Model 3 Standard Range',
#    'fuelType': 'electric',
#    'transmissionType': 'automatic'},
#   'isAlreadyInOption': False,
#   'expectedDeliveryDate': 'nvt',
#   'monthlyLeaseprice10KKmExVat': 'nvt',
#   'offerteurl': 'https://www.battmobility.be/offerte'},
#  {'displayName': 'Peugeot e-208 Kastanjestraat (Brugse Poort - Rooigem)<br/><i>Kastanjestraat 93, 9000 Gent</i>',
#   'imageUrl': 'https://www.battmobility.com/Assets/Images/Vehicles/VehicleTypeID45.png',
#   'brandIcon': 'https://www.battmobility.com/Assets/Images/BrandIcons/Brandicon_Peugeot.jpg',
#   'availableInFormula': ['BattFun', 'BattFan', 'BattFanPlus'],
#   'availability': 'active',
#   'baseAddress': 'Kastanjestraat 93, 9000 Gent',
#   'stationType': 'fixed',
#   'geoPosition': {'longitude': '3.6987100000', 'latitude': '51.0604300000'},
#   'vehicleInformation': {'brand': 'Peugeot',
#    'model': 'e-208',
#    'fuelType': 'electric',
#    'transmissionType': 'automatic'},
#   'isAlreadyInOption': False,
#   'expectedDeliveryDate': 'nvt',
#   'monthlyLeaseprice10KKmExVat': 'nvt',
#   'offerteurl': 'https://www.battmobility.be/offerte'},
#  {'displayName': 'Tesla Model 3 Kammerstraat<br/><i>Kammerstraat 299000 Gent Belgium, 9000 Gent</i>',
#   'imageUrl': 'https://www.battmobility.com/Assets/Images/Vehicles/VehicleTypeID37.png',
#   'brandIcon': 'https://www.battmobility.com/Assets/Images/BrandIcons/Brandicon_Tesla.jpg',
#   'availableInFormula': ['BattFanPlus'],
#   'availability': 'active',
#   'baseAddress': 'Kammerstraat 299000 Gent Belgium, 9000 Gent',
#   'stationType': 'fixed',
#   'geoPosition': {'longitude': '3.7042400000', 'latitude': '51.0585300000'},
#   'vehicleInformation': {'brand': 'Tesla',
#    'model': 'Model 3 Standard Range',
#    'fuelType': 'electric',
#    'transmissionType': 'automatic'},
#   'isAlreadyInOption': False,
#   'expectedDeliveryDate': 'nvt',
#   'monthlyLeaseprice10KKmExVat': 'nvt',
#   'offerteurl': 'https://www.battmobility.be/offerte'},
#  {'displayName': 'Peugeot e-208 - besteld',
#   'imageUrl': 'https://www.battmobility.com/Assets/Images/Vehicles/VehicleTypeID45.png',
#   'brandIcon': 'https://www.battmobility.com/Assets/Images/BrandIcons/Brandicon_Peugeot.jpg',
#   'availableInFormula': ['BattFun', 'BattFan', 'BattFanPlus'],
#   'availability': 'expected',
#   'baseAddress': '',
#   'stationType': 'fixed',
#   'geoPosition': {'longitude': '3.7298', 'latitude': '51.04333'},
#   'vehicleInformation': {'brand': 'Peugeot',
#    'model': 'e-208',
#    'fuelType': 'electric',
#    'transmissionType': 'automatic'},
#   'isAlreadyInOption': False,
#   'expectedDeliveryDate': 'nvt',
#   'monthlyLeaseprice10KKmExVat': 'nvt',
#   'offerteurl': 'https://www.battmobility.be/offerte'},
#  {'displayName': 'Peugeot e-208 Xavier de Cocklaan - besteld<br/><i>Xavier de Cocklaan 5, 9831 Sint-Martens-Latem</i>',
#   'imageUrl': 'https://www.battmobility.com/Assets/Images/Vehicles/VehicleTypeID45.png',
#   'brandIcon': 'https://www.battmobility.com/Assets/Images/BrandIcons/Brandicon_Peugeot.jpg',
#   'availableInFormula': ['BattFun', 'BattFan', 'BattFanPlus'],
#   'availability': 'expected',
#   'baseAddress': 'Xavier de Cocklaan 5, 9831 Sint-Martens-Latem',
#   'stationType': 'fixed',
#   'geoPosition': {'longitude': '3.6076131000', 'latitude': '50.9972094000'},
#   'vehicleInformation': {'brand': 'Peugeot',
#    'model': 'e-208',
#    'fuelType': 'electric',
#    'transmissionType': 'automatic'},
#   'isAlreadyInOption': False,
#   'expectedDeliveryDate': 'nvt',
#   'monthlyLeaseprice10KKmExVat': 'nvt',
#   'offerteurl': 'https://www.battmobility.be/offerte'},
#  {'displayName': 'Peugeot e-RifterLong Range (preorder leveringsdatum 5 May 2023)',
#   'imageUrl': 'https://www.battmobility.com/Assets/Images/Vehicles/VehicleTypeID51.png',
#   'brandIcon': 'https://www.battmobility.com/Assets/Images/BrandIcons/Brandicon_Peugeot.jpg',
#   'availableInFormula': ['BattFun', 'BattFan', 'BattFanPlus'],
#   'availability': 'preordered',
#   'baseAddress': '',
#   'stationType': 'fixed',
#   'geoPosition': {'longitude': '3.7298', 'latitude': '51.04333'},
#   'vehicleInformation': {'brand': 'Peugeot',
#    'model': 'e-Rifter',
#    'fuelType': 'electric',
#    'transmissionType': 'automatic'},
#   'isAlreadyInOption': False,
#   'expectedDeliveryDate': '5 May 2023',
#   'monthlyLeaseprice10KKmExVat': 'nvt',
#   'offerteurl': 'https://www.battmobility.be/offerte'},
#  {'displayName': 'Tesla Model 3 Vlasgaardstraat<br/><i>Vlasgaardstraat 52, 9000 Gent</i>',
#   'imageUrl': 'https://www.battmobility.com/Assets/Images/Vehicles/VehicleTypeID37.png',
#   'brandIcon': 'https://www.battmobility.com/Assets/Images/BrandIcons/Brandicon_Tesla.jpg',
#   'availableInFormula': ['BattFanPlus'],
#   'availability': 'active',
#   'baseAddress': 'Vlasgaardstraat 52, 9000 Gent',
#   'stationType': 'fixed',
#   'geoPosition': {'longitude': '3.7011962000', 'latitude': '51.0565667000'},
#   'vehicleInformation': {'brand': 'Tesla',
#    'model': 'Model 3 Standard Range',
#    'fuelType': 'electric',
#    'transmissionType': 'automatic'},
#   'isAlreadyInOption': False,
#   'expectedDeliveryDate': 'nvt',
#   'monthlyLeaseprice10KKmExVat': 'nvt',
#   'offerteurl': 'https://www.battmobility.be/offerte'},
#  {'displayName': 'Peugeot e-Rifter Lousbergkaai - besteld<br/><i>Ferdinand Lousbergskaai 98, 9000 Gent</i>',
#   'imageUrl': 'https://www.battmobility.com/Assets/Images/Vehicles/VehicleTypeID51.png',
#   'brandIcon': 'https://www.battmobility.com/Assets/Images/BrandIcons/Brandicon_Peugeot.jpg',
#   'availableInFormula': ['BattFun', 'BattFan', 'BattFanPlus'],
#   'availability': 'expected',
#   'baseAddress': 'Ferdinand Lousbergskaai 98, 9000 Gent',
#   'stationType': 'fixed',
#   'geoPosition': {'longitude': '3.7394385000', 'latitude': '51.0476650000'},
#   'vehicleInformation': {'brand': 'Peugeot',
#    'model': 'e-Rifter',
#    'fuelType': 'electric',
#    'transmissionType': 'automatic'},
#   'isAlreadyInOption': False,
#   'expectedDeliveryDate': 'nvt',
#   'monthlyLeaseprice10KKmExVat': 'nvt',
#   'offerteurl': 'https://www.battmobility.be/offerte'},
#  {'displayName': 'Peugeot e-208 Sint-Pietersaalststraat<br/><i>Sint-Pietersaalststraat 59, 9000 Gent</i>',
#   'imageUrl': 'https://www.battmobility.com/Assets/Images/Vehicles/VehicleTypeID45.png',
#   'brandIcon': 'https://www.battmobility.com/Assets/Images/BrandIcons/Brandicon_Peugeot.jpg',
#   'availableInFormula': ['BattFun', 'BattFan', 'BattFanPlus'],
#   'availability': 'active',
#   'baseAddress': 'Sint-Pietersaalststraat 59, 9000 Gent',
#   'stationType': 'fixed',
#   'geoPosition': {'longitude': '3.7154595000', 'latitude': '51.0306519000'},
#   'vehicleInformation': {'brand': 'Peugeot',
#    'model': 'e-208',
#    'fuelType': 'electric',
#    'transmissionType': 'automatic'},
#   'isAlreadyInOption': False,
#   'expectedDeliveryDate': 'nvt',
#   'monthlyLeaseprice10KKmExVat': 'nvt',
#   'offerteurl': 'https://www.battmobility.be/offerte'},
#  {'displayName': 'Opel e-Combo Melle<br/><i>Rootputte 35, 9090 Melle</i>',
#   'imageUrl': 'https://www.battmobility.com/Assets/Images/Vehicles/VehicleTypeID61.png',
#   'brandIcon': 'https://www.battmobility.com/Assets/Images/BrandIcons/Brandicon_Opel.jpg',
#   'availableInFormula': ['BattFun', 'BattFan', 'BattFanPlus'],
#   'availability': 'active',
#   'baseAddress': 'Rootputte 35, 9090 Melle',
#   'stationType': 'fixed',
#   'geoPosition': {'longitude': '3.7791190000', 'latitude': '51.0174490000'},
#   'vehicleInformation': {'brand': 'Opel',
#    'model': 'e-Combo',
#    'fuelType': 'electric',
#    'transmissionType': 'automatic'},
#   'isAlreadyInOption': False,
#   'expectedDeliveryDate': 'nvt',
#   'monthlyLeaseprice10KKmExVat': 'nvt',
#   'offerteurl': 'https://www.battmobility.be/offerte'},
#  {'displayName': 'Peugeot e-208GT (preorder leveringsdatum 5 May 2023)',
#   'imageUrl': 'https://www.battmobility.com/Assets/Images/Vehicles/VehicleTypeID45.png',
#   'brandIcon': 'https://www.battmobility.com/Assets/Images/BrandIcons/Brandicon_Peugeot.jpg',
#   'availableInFormula': ['BattFun', 'BattFan', 'BattFanPlus'],
#   'availability': 'preordered',
#   'baseAddress': '',
#   'stationType': 'fixed',
#   'geoPosition': {'longitude': '3.7298', 'latitude': '51.04333'},
#   'vehicleInformation': {'brand': 'Peugeot',
#    'model': 'e-208',
#    'fuelType': 'electric',
#    'transmissionType': 'automatic'},
#   'isAlreadyInOption': False,
#   'expectedDeliveryDate': '5 May 2023',
#   'monthlyLeaseprice10KKmExVat': 'nvt',
#   'offerteurl': 'https://www.battmobility.be/offerte'},
#  {'displayName': 'Ioniq 5 Paviljoenweg<br/><i>Staf Bruggenstraat 15 , 9000 Gent</i>',
#   'imageUrl': 'https://www.battmobility.com/Assets/Images/Vehicles/VehicleTypeID41.png',
#   'brandIcon': 'https://www.battmobility.com/Assets/Images/BrandIcons/Brandicon_Hyundai.jpg',
#   'availableInFormula': ['BattFun', 'BattFan', 'BattFanPlus'],
#   'availability': 'active',
#   'baseAddress': 'Staf Bruggenstraat 15 , 9000 Gent',
#   'stationType': 'fixed',
#   'geoPosition': {'longitude': '3.7366500000', 'latitude': '51.0526900000'},
#   'vehicleInformation': {'brand': 'Hyundai',
#    'model': 'Ioniq 5',
#    'fuelType': 'electric',
#    'transmissionType': 'automatic'},
#   'isAlreadyInOption': False,
#   'expectedDeliveryDate': 'nvt',
#   'monthlyLeaseprice10KKmExVat': 'nvt',
#   'offerteurl': 'https://www.battmobility.be/offerte'},
#  {'displayName': 'Twizy Muinkkaai (Binnenstad)<br/><i>Muinkkaai 53, 9000 Gent</i>',
#   'imageUrl': 'https://www.battmobility.com/Assets/Images/Vehicles/VehicleTypeID21.png',
#   'brandIcon': 'https://www.battmobility.com/Assets/Images/BrandIcons/Brandicon_Renault.jpg',
#   'availableInFormula': ['BattFun', 'BattFan', 'BattFanPlus'],
#   'availability': 'active',
#   'baseAddress': 'Muinkkaai 53, 9000 Gent',
#   'stationType': 'fixed',
#   'geoPosition': {'longitude': '3.7289425000', 'latitude': '51.0438103000'},
#   'vehicleInformation': {'brand': 'Renault',
#    'model': 'Twizy',
#    'fuelType': 'electric',
#    'transmissionType': 'automatic'},
#   'isAlreadyInOption': False,
#   'expectedDeliveryDate': 'nvt',
#   'monthlyLeaseprice10KKmExVat': 'nvt',
#   'offerteurl': 'https://www.battmobility.be/offerte'}]
